# %%
import pandas as pd

# %%
dataset=pd.read_csv('Untitled spreadsheet - Yashwanth - Sheet2.csv')

# %%
import sys

# %%
import markovclick

# %%
import seaborn as sns

# %%
import numpy as np
import matplotlib as plt

# %%
dataset.head()
# Out:
#    1  A1 A1.1 A1.2 Unnamed: 4 Unnamed: 5
# 0  2  A1   A1   A1        NaN        NaN
# 1  3  A1   A1   A1        NaN        NaN
# 2  4  A1   A1   A1        NaN        NaN
# 3  5  A1   A1   A1         A1         A1
# 4  6  A1  NaN  NaN        NaN        NaN

# %%
dataset
# Out:
#      1  A1 A1.1 A1.2 Unnamed: 4 Unnamed: 5
# 0    2  A1   A1   A1        NaN        NaN
# 1    3  A1   A1   A1        NaN        NaN
# 2    4  A1   A1   A1        NaN        NaN
# 3    5  A1   A1   A1         A1         A1
# 4    6  A1  NaN  NaN        NaN        NaN
# 5    7  A1  NaN  NaN        NaN        NaN
# 6    8  A1  NaN  NaN        NaN        NaN
# 7    9  A1  NaN  NaN        NaN        NaN
# 8   10  A1  NaN  NaN        NaN        NaN
# 9   11  A1  NaN  NaN        NaN        NaN
# 10  12  A1  NaN  NaN        NaN        NaN
# 11  13  A1  NaN  NaN        NaN        NaN
# 12  14  A1  NaN  NaN        NaN        NaN
# 13  15  A1  NaN  NaN        NaN        NaN
# 14  16  A1  NaN  NaN        NaN        NaN
# 15  17  A1  NaN  NaN        NaN        NaN
# 16  18  A1  NaN  NaN        NaN        NaN
# 17  19  A1  NaN  NaN        NaN        NaN
# 18  20  A1  NaN  NaN        NaN        NaN
# 19  21  A1  NaN  NaN        NaN        NaN
# 20  22  A1  NaN  NaN        NaN        NaN
# 21  23  A1  NaN  NaN        NaN        NaN
# 22  24  A1  NaN  NaN        NaN        NaN
# 23  25  A1  NaN  NaN        NaN        NaN
# 24  26  A1   A1  NaN        NaN        NaN
# 25  27  A1  NaN  NaN        NaN        NaN
# 26  28  A1  NaN  NaN        NaN        NaN
# 27  29  A1  NaN  NaN        NaN        NaN
# 28  30  A1  NaN  NaN        NaN        NaN
# 29  31  A1  NaN  NaN        NaN        NaN
# ..  ..  ..  ...  ...        ...        ...
# 44  46  A1  NaN  NaN        NaN        NaN
# 45  47  A1  NaN  NaN        NaN        NaN
# 46  48  A1  NaN  NaN        NaN        NaN
# 47  49  A1  NaN  NaN        NaN        NaN
# 48  50  A1  NaN  NaN        NaN        NaN
# 49  51  A1   A1   A1         A1        NaN
# 50  52  A1  NaN  NaN        NaN        NaN
# 51  53  A1  NaN  NaN        NaN        NaN
# 52  54  A1  NaN  NaN        NaN        NaN
# 53  55  A1  NaN  NaN        NaN        NaN
# 54  56  A1  NaN  NaN        NaN        NaN
# 55  57  A1  NaN  NaN        NaN        NaN
# 56  58  A1  NaN  NaN        NaN        NaN
# 57  59  A1   A1  NaN        NaN        NaN
# 58  60  A1  NaN  NaN        NaN        NaN
# 59  61  A1  NaN  NaN        NaN        NaN
# 60  62  A1  NaN  NaN        NaN        NaN
# 61  63  A1  NaN  NaN        NaN        NaN
# 62  64  A1  NaN  NaN        NaN        NaN
# 63  65  A1  NaN  NaN        NaN        NaN
# 64  66  A1  NaN  NaN        NaN        NaN
# 65  67  A1  NaN  NaN        NaN        NaN
# 66  68  A1  NaN  NaN        NaN        NaN
# 67  69  A1  NaN  NaN        NaN        NaN
# 68  70  A1   A1   A1         A1        NaN
# 69  71  A1  NaN  NaN        NaN        NaN
# 70  72  A1  NaN  NaN        NaN        NaN
# 71  73  A1  NaN  NaN        NaN        NaN
# 72  74  A1  NaN  NaN        NaN        NaN
# 73  75  A1  NaN  NaN        NaN        NaN
#
# [74 rows x 6 columns]

# %%
dataset.set_index(dataset.columns[0],inplace=True)

# %%
data=[]
for i in range(74):
    x=dataset.values[i]
    x=x[~pd.isnull(x)]
    data.append(x)
data
# Out:
# [array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object)]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(data)

# %%
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages)
